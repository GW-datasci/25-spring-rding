# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from datetime import datetime
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# Load a sample from each dataset
dfs = {
    "zhvi": load_data("zhvi_home_values.csv"),
    "zhvf": load_data("zhvf_forecast_growth.csv"),
    "median_price": load_data("median_sale_price.csv"),
    "inventory": load_data("inventory_active_listings.csv"),
    "income_needed": load_data("income_needed_downpayment.csv")
}

# %%
# Check common columns
for name, df in dfs.items():
    print(f"🔹 {name.upper()} Columns:")
    print(df.columns)
    print("-" * 50)
